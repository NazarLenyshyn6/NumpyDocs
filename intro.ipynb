# %%
# NumPy is the fundamental package for scientific computing in Python.
# It is a Python library that provides a multidimensional array object, various 
# derivde objects (such as masked arrays and matrices), and as assortement or routines
# for fast operatoins on arrays, including mathematical, logical, shape manipulation,
# sorting, selection, I/O, dicrete Fouries transforms, basic linear algebra
# basic statistical operations, random simulations and much more.
